# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcioMonteiro1511/ASSOPESCA/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando bibliotecas necessárias

from nltk.chat.util import Chat, reflections

# Definindo pares de perguntas e respostas

pairs = [

  ["olá", ["Olá! Como posso ajudá-lo hoje?"]],
   ["oi", ["Olá! Como posso ajudá-lo hoje?"]],
   ["bom dia", ["Olá! Como posso ajudá-lo hoje?"]],
   ["boa noite", ["Olá! Como posso ajudá-lo hoje?"]],

  ["como faço para renovar meu documento?",

   ["Você pode renovar seus documentos acessando o site do órgão responsável ou comparecendo a uma unidade próxima."]],

  ["quais documentos eu preciso?",

   ["Você precisará de um documento de identificação, comprovante de residência e CPF."]],

  ["obrigado", ["De nada! Estou aqui para ajudar."]],

  ["tchau", ["Até logo! Tenha um ótimo dia."]]

]

# Criando o chatbot

chatbot = Chat(pairs, reflections)

# Iniciando o chatbot

print("Bem-vindo ao Chatbot de Serviços Públicos!")

print("Digite 'sair' para encerrar o atendimento.")

while True:

  user_input = input("Você: ")

  if user_input.lower() == "sair":

      print("Chatbot: Até logo! Espero ter ajudado.")

      break

  response = chatbot.respond(user_input)

  if response:

      print(f"Chatbot: {response}")

  else:

      print("Chatbot: Desculpe, não entendi sua pergunta. Por favor, tente novamente.")
# Out:
# Bem-vindo ao Chatbot de Serviços Públicos!
# Digite 'sair' para encerrar o atendimento.
# Você: oi
# Chatbot: Olá! Como posso ajudá-lo hoje?
# Você: bom dia
# Chatbot: Olá! Como posso ajudá-lo hoje?
# Você: dia
# Chatbot: Desculpe, não entendi sua pergunta. Por favor, tente novamente.
# Você: sair
# Chatbot: Até logo! Espero ter ajudado.
